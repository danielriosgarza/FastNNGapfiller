# %% [markdown]
# Load dependencies

# %%
import numpy as np
import pandas as pd
import os
import sys
import json
import tensorflow as tf
import NN_Predictor

# %%
from pathlib import Path
path = Path.cwd()
sys.path.append(path)
file_path = os.path.join(path.parent,'files', 'NN')
output_path = os.path.join(path.parent,'files', 'custom scores')
rxn_ids = np.load(file_path+'/rxn_ids.npy').astype('str')

#Tensorflow complains because the NN is not optimized perfectly
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# ## Introduction
#
# The purpose of this notebook is to show some examples of using the NN

# %% [markdown]
# ## Making predictions using the NN
#
# Load in your favourite Neural Network

# %%
NN = NN_Predictor.load_NN(path=file_path+'/NN_full.h5')
# Out:
# 2022-01-20 16:24:33.114324: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-20 16:24:33.144216: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3192695000 Hz
# 2022-01-20 16:24:33.145568: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55975952cff0 executing computations on platform Host. Devices:
# 2022-01-20 16:24:33.145603: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version
# 2022-01-20 16:24:33.149296: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# Load in the data, the current NN requires a binary list indicating presences of reactions, important is that this is in the right order (maybe something that I can solve).
# First lets try it with a single reaction set

# %%
input_data = np.load(file_path+'/example_binary.npy')

# %% [markdown]
# This example already has the right order so no worries, we can immediately make our prediction

# %%
prediction = NN_Predictor.make_prediction(input_data,NN)

# %% [markdown]
# We can then save this as an dictionary (.json) so we know which prediction corresponds to which reaction

# %%
pdic = dict(zip(rxn_ids,prediction.astype('float')))
p_file = open(output_path+"/prediction_example.json", 'w')
json.dump(pdic, p_file)
p_file.close()

# %%
pdic
# Out:
# {'rxn00708_c': 0.760888397693634,
#  'rxn03236_c': 0.9464927315711975,
#  'rxn00611_c': 0.15143105387687683,
#  'rxn07435_c': 0.9705636501312256,
#  'rxn05746_c': 0.21239891648292542,
#  'rxn01678_c': 0.947871208190918,
#  'rxn00289_c': 0.7557255625724792,
#  'rxn02201_c': 0.12500518560409546,
#  'rxn05561_c': 0.11122691631317139,
#  'rxn02286_c': 0.28739410638809204,
#  'rxn00394_c': 0.20634570717811584,
#  'rxn07433_c': 0.33714747428894043,
#  'rxn07431_c': 0.9566936492919922,
#  'rxn05567_c': 0.8707337379455566,
#  'rxn01265_c': 0.22565758228302002,
#  'rxn00836_c': 0.9200906157493591,
#  'rxn08977_c': 0.8182903528213501,
#  'rxn00642_c': 0.6981823444366455,
#  'rxn00874_c': 0.2900041341781616,
#  'rxn00834_c': 0.29496458172798157,
#  'rxn05527_c': 0.9285405278205872,
#  'rxn08180_c': 0.15021759271621704,
#  'rxn01269_c': 0.8876037001609802,
#  'rxn00872_c': 0.46971264481544495,
#  'rxn05563_c': 0.7852461338043213,
#  'rxn05318_c': 0.751314640045166,
#  'rxn00782_c': 0.565354585647583,
#  'rxn00392_c': 0.8438130617141724,
#  'rxn00747_c': 0.20930099487304688,
#  'rxn00832_c': 0.1148364245891571,
#  'rxn00830_c': 0.5655561685562134,
#  'rxn04599_c': 0.8645578026771545,
#  'rxn09699_c': 0.30087047815322876,
#  'rxn10191_c': 0.006538510322570801,
#  'rxn01108_c': 0.17410317063331604,
#  'rxn05219_c': 0.9639203548431396,
#  'rxn10113_c': 0.9968884587287903,
#  'rxn10292_c': 0.9486500024795532,
#  'rxn08709_c': 0.7115044593811035,
#  'rxn05958_c': 0.9282553195953369,
#  'rxn00423_c': 0.8848793506622314,
#  'rxn10298_c': 0.8636970520019531,
#  'rxn00364_c': 0.22230592370033264,
#  'rxn00879_c': 0.7748163342475891,
#  'rxn01639_c': 0.854576051235199,
#  'rxn05409_c': 0.9509073495864868,
#  'rxn01106_c': 0.639246940612793,
#  'rxn10150_c': 0.11025917530059814,
#  'rxn05405_c': 0.8912503719329834,
#  'rxn09154_c': 0.9492105841636658,
#  'rxn09126_c': 0.965974748134613,
#  'rxn09124_c': 0.5789394974708557,
#  'rxn00029_c': 0.7813127636909485,
#  'rxn05189_c': 0.9795124530792236,
#  'rxn05407_c': 0.7479398846626282,
#  'rxn00351_c': 0.2037663459777832,
#  'rxn00704_c': 0.514855146408081,
#  'rxn09150_c': 0.3486102223396301,
#  'rxn00609_c': 0.8555058836936951,
#  'rxn06673_c': 0.2704138457775116,
#  'rxn10193_c': 0.32224491238594055,
#  'rxn09156_c': 0.12060320377349854,
#  'rxn12640_c': 0.2735567092895508,
#  'rxn05250_c': 0.5114668011665344,
#  'rxn01459_c': 0.9123308658599854,
#  'rxn05440_c': 0.8847740888595581,
#  'rxn03643_c': 0.41224852204322815,
#  'rxn12646_c': 0.7221943140029907,
#  'rxn05252_c': 0.19845861196517944,
#  'rxn01671_c': 0.21717128157615662,
#  'rxn05442_c': 0.09268644452095032,
#  'rxn05402_c': 0.7101104259490967,
#  'rxn06777_c': 0.860828161239624,
#  'rxn03869_c': 0.06562501192092896,
#  'rxn01630_c': 0.6480804681777954,
#  'rxn00935_c': 0.02931329607963562,
#  'rxn05256_c': 0.5936496257781982,
#  'rxn05404_c': 0.5891952514648438,
#  'rxn01673_c': 0.24430608749389648,
#  'rxn05446_c': 0.2283734381198883,
#  'rxn10209_c': 0.9459723234176636,
#  'rxn02175_c': 0.8237600326538086,
#  'rxn05313_c': 0.8569801449775696,
#  'rxn05211_c': 0.2541806697845459,
#  'rxn01634_c': 0.7385465502738953,
#  'rxn00931_c': 0.3478080630302429,
#  'rxn00245_c': 0.13984674215316772,
#  'rxn00247_c': 0.14147108793258667,
#  'rxn05625_c': 0.19571101665496826,
#  'rxn05444_c': 0.3491637110710144,
#  'rxn10205_c': 0.6171102523803711,
#  'rxn05400_c': 0.41412127017974854,
#  'rxn05317_c': 0.8434147834777832,
#  'rxn00066_c': 0.16391068696975708,
#  'rxn01188_c': 0.9580827355384827,
#  'rxn05422_c': 0.08528152108192444,
#  'rxn08756_c': 0.48880502581596375,
#  'rxn10117_c': 0.8626779317855835,
#  'rxn01450_c': 0.9815015196800232,
#  'rxn01278_c': 0.7929724454879761,
#  'rxn10295_c': 0.6924684047698975,
#  'rxn05156_c': 0.3018915355205536,
#  'rxn05154_c': 0.1887551248073578,
#  'rxn08470_c': 0.06734171509742737,
#  'rxn10339_c': 0.9959665536880493,
#  'rxn00020_c': 0.5452653169631958,
#  'rxn01452_c': 0.15352419018745422,
#  'rxn05620_c': 0.37390968203544617,
#  'rxn10291_c': 0.6435814499855042,
#  'rxn10010_c': 0.3389270603656769,
#  'rxn02900_c': 0.1547369360923767,
#  'rxn02835_c': 0.9834100008010864,
#  'rxn00022_c': 0.3579791188240051,
#  'rxn02885_c': 0.12486988306045532,
#  'rxn10297_c': 0.5656993985176086,
#  'rxn10012_c': 0.6316065788269043,
#  'rxn00932_c': 0.6574989557266235,
#  'rxn11702_c': 0.6419572234153748,
#  'rxn03884_c': 0.9354612827301025,
#  'rxn00938_c': 0.441547155380249,
#  'rxn01332_c': 0.07593303918838501,
#  'rxn04385_c': 0.12485182285308838,
#  'rxn00975_c': 0.1311931014060974,
#  'rxn04938_c': 0.9667837619781494,
#  'rxn02431_c': 0.23937678337097168,
#  'rxn00973_c': 0.5918582677841187,
#  'rxn05667_c': 0.42126965522766113,
#  'rxn01675_c': 0.9521729946136475,
#  'rxn05117_c': 0.6861392855644226,
#  'rxn00410_c': 0.10909640789031982,
#  'rxn05351_c': 0.09026288986206055,
#  'rxn10273_c': 0.9801769256591797,
#  'rxn05347_c': 0.47380122542381287,
#  'rxn02000_c': 0.2766403555870056,
#  'rxn03239_c': 0.40229079127311707,
#  'rxn00412_c': 0.9656286239624023,
#  'rxn10275_c': 0.27339285612106323,
#  'rxn03933_c': 0.21217474341392517,
#  'rxn05459_c': 0.2761923670768738,
#  'rxn01573_c': 0.6190001964569092,
#  'rxn00414_c': 0.4392690062522888,
#  'rxn00416_c': 0.8700288534164429,
#  'rxn00324_c': 0.36511021852493286,
#  'rxn08839_c': 0.8672763109207153,
#  'rxn00650_c': 0.4958515763282776,
#  'rxn10094_c': 0.30180782079696655,
#  'rxn02632_c': 0.5567134618759155,
#  'rxn05216_c': 0.7233562469482422,
#  'rxn00322_c': 0.49457454681396484,
#  'rxn03167_c': 0.8662401437759399,
#  'rxn03883_c': 0.8769280910491943,
#  'rxn09692_c': 0.27573034167289734,
#  'rxn00654_c': 0.031084179878234863,
#  'rxn00278_c': 0.37794533371925354,
#  'rxn03536_c': 0.2860574722290039,
#  'rxn05152_c': 0.8415593504905701,
#  'rxn00640_c': 0.4211164116859436,
#  'rxn01575_c': 0.8643854856491089,
#  'rxn05239_c': 0.6745617985725403,
#  'rxn01454_c': 0.2950882017612457,
#  'rxn05150_c': 0.8062320947647095,
#  'rxn00785_c': 0.0712418258190155,
#  'rxn00656_c': 0.1103827953338623,
#  'rxn02883_c': 0.9946283102035522,
#  'rxn00693_c': 0.8699740767478943,
#  'rxn01103_c': 0.5488818883895874,
#  'rxn01313_c': 0.06696584820747375,
#  'rxn12844_c': 0.5333578586578369,
#  'rxn01827_c': 0.4971490204334259,
#  'rxn03909_c': 0.6726240515708923,
#  'rxn01315_c': 0.7486240267753601,
#  'rxn01868_c': 0.07388320565223694,
#  'rxn10278_c': 0.5863961577415466,
#  'rxn00105_c': 0.5616387128829956,
#  'rxn08201_c': 0.8108166456222534,
#  'rxn10806_c': 0.25558820366859436,
#  'rxn13783_c': 0.522019624710083,
#  'rxn10118_c': 0.5045225024223328,
#  'rxn00225_c': 0.9668640494346619,
#  'rxn05392_c': 0.6737895607948303,
#  'rxn12008_c': 0.2702341079711914,
#  'rxn00101_c': 0.43201303482055664,
#  'rxn09562_c': 0.07586508989334106,
#  'rxn00223_c': 0.630555272102356,
#  'rxn05359_c': 0.9860677719116211,
#  'rxn01945_c': 0.2851307690143585,
#  'rxn09159_c': 0.7422105073928833,
#  'rxn10277_c': 0.29070067405700684,
#  'rxn04600_c': 0.5021156668663025,
#  'rxn04602_c': 0.8977000117301941,
#  'rxn04070_c': 0.06541237235069275,
#  'rxn08936_c': 0.604411780834198,
#  'rxn00199_c': 0.12406745553016663,
#  'rxn00227_c': 0.10443392395973206,
#  'rxn00515_c': 0.16243508458137512,
#  'rxn00355_c': 0.4323449730873108,
#  'rxn03433_c': 0.1606641411781311,
#  'rxn08848_c': 0.19722291827201843,
#  'rxn08846_c': 0.32641103863716125,
#  'rxn10231_c': 0.12794196605682373,
#  'rxn03084_c': 0.3491649627685547,
#  'rxn00511_c': 0.27273738384246826,
#  'rxn01828_c': 0.5017105340957642,
#  'rxn05397_c': 0.20618730783462524,
#  'rxn03435_c': 0.9665132761001587,
#  'rxn10233_c': 0.07064393162727356,
#  'rxn06600_c': 0.616172194480896,
#  'rxn03439_c': 0.8708873391151428,
#  'rxn00216_c': 0.6356357932090759,
#  'rxn03080_c': 0.19872865080833435,
#  'rxn05012_c': 0.9816329479217529,
#  'rxn02944_c': 0.6314180493354797,
#  'rxn01867_c': 0.2546754479408264,
#  'rxn03437_c': 0.07790088653564453,
#  'rxn10237_c': 0.984976589679718,
#  'rxn03086_c': 0.18321725726127625,
#  'rxn01353_c': 0.9530044794082642,
#  'rxn02005_c': 0.9613808989524841,
#  'rxn08205_c': 0.887810468673706,
#  'rxn00251_c': 0.08820709586143494,
#  'rxn10235_c': 0.40579891204833984,
#  'rxn01044_c': 0.05962175130844116,
#  'rxn10270_c': 0.8629764318466187,
#  'rxn01252_c': 0.9385355710983276,
#  'rxn12633_c': 0.6333459615707397,
#  'rxn00882_c': 0.07587432861328125,
#  'rxn10011_c': 0.9038270711898804,
#  'rxn05578_c': 0.9974119663238525,
#  'rxn08808_c': 0.9423798322677612,
#  'rxn00558_c': 0.6550900936126709,
#  'rxn04724_c': 0.9815912246704102,
#  'rxn12637_c': 0.04352042078971863,
#  'rxn12635_c': 0.5462586283683777,
#  'rxn04139_c': 0.14092859625816345,
#  'rxn00346_c': 0.05410146713256836,
#  'rxn05297_c': 0.9415533542633057,
#  'rxn01385_c': 0.024863719940185547,
#  'rxn00172_c': 0.13136997818946838,
#  'rxn01219_c': 0.1224706768989563,
#  'rxn07845_c': 0.014150857925415039,
#  'rxn02168_c': 0.7355058193206787,
#  'rxn12644_c': 0.972205638885498,
#  'rxn01476_c': 0.22796976566314697,
#  'rxn12638_c': 0.0678320825099945,
#  'rxn00222_c': 0.9895660877227783,
#  'rxn01387_c': 0.1090807318687439,
#  'rxn00552_c': 0.1518850326538086,
#  'rxn00612_c': 0.8818037509918213,
#  'rxn00800_c': 0.5865057110786438,
#  'rxn03127_c': 0.6793864369392395,
#  'rxn01859_c': 0.42654451727867126,
#  'rxn00194_c': 0.8842191696166992,
#  'rxn05539_c': 0.9533486366271973,
#  'rxn08841_c': 0.3340073823928833,
#  'rxn01187_c': 0.2599581480026245,
#  'rxn00806_c': 0.850651741027832,
#  'rxn02369_c': 0.6669964790344238,
#  'rxn05571_c': 0.9677468538284302,
#  'rxn01857_c': 0.3289563059806824,
#  'rxn00849_c': 0.41689860820770264,
#  'rxn08845_c': 0.820805549621582,
#  'rxn00737_c': 0.23469170928001404,
#  'rxn01259_c': 0.1489158272743225,
#  'rxn01705_c': 0.8576608896255493,
#  'rxn08943_c': 0.9783114194869995,
#  'rxn05292_c': 0.7756891250610352,
#  'rxn08843_c': 0.7466250658035278,
#  'rxn09177_c': 0.059170305728912354,
#  'rxn06723_c': 0.032567739486694336,
#  'rxn05328_c': 0.26756608486175537,
#  'rxn00313_c': 0.4876960515975952,
#  'rxn02949_c': 0.5843791365623474,
#  'rxn00179_c': 0.0990237295627594,
#  'rxn01256_c': 0.4264868497848511,
#  'rxn04052_c': 0.8160796761512756,
#  'rxn00880_c': 0.902146577835083,
#  'rxn02945_c': 0.286705881357193,
#  'rxn00213_c': 0.12169170379638672,
#  'rxn05682_c': 0.8699672818183899,
#  'rxn00605_c': 0.3836557865142822,
#  'rxn03040_c': 0.15398508310317993,
#  'rxn05199_c': 0.13507577776908875,
#  'rxn05160_c': 0.8417072892189026,
#  'rxn00786_c': 0.495962530374527,
#  'rxn10162_c': 0.8536694049835205,
#  'rxn10288_c': 0.5287832617759705,
#  'rxn01629_c': 0.7462573051452637,
#  'rxn10537_c': 0.9888347387313843,
#  'rxn00777_c': 0.20003852248191833,
#  'rxn05164_c': 0.6425536274909973,
#  'rxn01210_c': 0.9697171449661255,
#  'rxn10160_c': 0.9237347841262817,
#  'rxn05162_c': 0.07499554753303528,
#  'rxn09134_c': 0.9745550155639648,
#  'rxn02680_c': 0.732704758644104,
#  'rxn13784_c': 0.9440062046051025,
#  'rxn10571_c': 0.45547571778297424,
#  'rxn05361_c': 0.5097596645355225,
#  'rxn00192_c': 0.08445659279823303,
#  'rxn01740_c': 0.6902763247489929,
#  'rxn05533_c': 0.7493832111358643,
#  'rxn01851_c': 0.10249745845794678,
#  'rxn00804_c': 0.12219473719596863,
#  'rxn00196_c': 0.38959524035453796,
#  'rxn01218_c': 0.943024754524231,
#  'rxn05535_c': 0.8705399036407471,
#  'rxn05537_c': 0.9447987675666809,
#  'rxn02296_c': 0.23937338590621948,
#  'rxn08178_c': 0.3587358295917511,
#  'rxn03954_c': 0.3255165219306946,
#  'rxn05573_c': 0.9563567638397217,
#  'rxn05367_c': 0.4971904456615448,
#  'rxn00190_c': 0.33286017179489136,
#  'rxn00615_c': 0.33498191833496094,
#  'rxn00547_c': 0.2437574565410614,
#  'rxn01620_c': 0.12470090389251709,
#  'rxn05201_c': 0.9689739942550659,
#  'rxn05327_c': 0.9650771617889404,
#  'rxn00505_c': 0.09149885177612305,
#  'rxn10312_c': 0.18228980898857117,
#  'rxn04750_c': 0.13661280274391174,
#  'rxn05619_c': 0.9765915274620056,
#  'rxn03630_c': 0.32092881202697754,
#  'rxn05205_c': 0.8649982213973999,
#  'rxn05323_c': 0.20210126042366028,
#  'rxn05192_c': 0.08684042096138,
#  'rxn01626_c': 0.7342169284820557,
#  'rxn05325_c': 0.8591001033782959,
#  'rxn00509_c': 0.21159514784812927,
#  'rxn02898_c': 0.07446867227554321,
#  'rxn05207_c': 0.8701920509338379,
#  'rxn10280_c': 0.9023452997207642,
#  'rxn05654_c': 0.06783968210220337,
#  'rxn05656_c': 0.4453775882720947,
#  'rxn01199_c': 0.3934262990951538,
#  'rxn10123_c': 0.7839629054069519,
#  'rxn09130_c': 0.9282410144805908,
#  'rxn11040_c': 0.6305830478668213,
#  'rxn05538_c': 0.40404701232910156,
#  'rxn09132_c': 0.21793949604034424,
#  'rxn10168_c': 0.057092875242233276,
#  'rxn01370_c': 0.10067230463027954,
#  'rxn02760_c': 0.17789188027381897,
#  'rxn05616_c': 0.535023033618927,
#  'rxn01279_c': 0.5000931620597839,
#  'rxn02762_c': 0.14747557044029236,
#  'rxn05610_c': 0.06537690758705139,
#  'rxn01911_c': 0.9807766675949097,
#  'rxn03249_c': 0.36832550168037415,
#  'rxn02319_c': 0.3557994067668915,
#  'rxn08807_c': 0.32050228118896484,
#  'rxn10306_c': 0.8603237867355347,
#  'rxn05614_c': 0.465600848197937,
#  'rxn05433_c': 0.45236507058143616,
#  'rxn05655_c': 0.12543070316314697,
#  'rxn08805_c': 0.983008861541748,
#  'rxn11941_c': 0.24952489137649536,
#  'rxn01406_c': 0.6708318591117859,
#  'rxn10302_c': 0.8898502588272095,
#  'rxn01507_c': 0.18347787857055664,
#  'rxn02314_c': 0.9758986234664917,
#  'rxn05437_c': 0.10483267903327942,
#  'rxn01790_c': 0.0637359619140625,
#  'rxn08803_c': 0.772794246673584,
#  'rxn01663_c': 0.5673767328262329,
#  'rxn08801_c': 0.07817837595939636,
#  'rxn10304_c': 0.17946857213974,
#  'rxn01053_c': 0.35299253463745117,
#  'rxn02465_c': 0.07366624474525452,
#  'rxn02161_c': 0.31410151720046997,
#  'rxn05555_c': 0.3881392478942871,
#  'rxn05431_c': 0.30861926078796387,
#  'rxn05244_c': 0.18447411060333252,
#  'rxn05651_c': 0.42768266797065735,
#  'rxn00503_c': 0.7027925848960876,
#  'rxn00927_c': 0.6002165079116821,
#  'rxn00077_c': 0.9492541551589966,
#  'rxn01388_c': 0.8251643776893616,
#  'rxn09128_c': 0.1353590190410614,
#  'rxn05470_c': 0.14799374341964722,
#  'rxn02312_c': 0.9740272760391235,
#  'rxn00501_c': 0.20336946845054626,
#  'rxn05362_c': 0.22689643502235413,
#  'rxn00784_c': 0.9830485582351685,
#  'rxn00792_c': 0.3253626227378845,
#  'rxn03638_c': 0.06036800146102905,
#  'rxn01545_c': 0.08402815461158752,
#  'rxn02177_c': 0.27502989768981934,
#  'rxn05208_c': 0.8808928728103638,
#  'rxn10344_c': 0.01735377311706543,
#  'rxn00674_c': 0.035661160945892334,
#  'rxn05438_c': 0.9457663297653198,
#  'rxn02897_c': 0.9822064638137817,
#  'rxn10301_c': 0.8864962458610535,
#  'rxn07587_c': 0.4759604334831238,
#  'rxn02895_c': 0.2142106592655182,
#  'rxn00690_c': 0.829835057258606,
#  'rxn05126_c': 0.3561294674873352,
#  'rxn01483_c': 0.2543754279613495,
#  'rxn05434_c': 0.46567502617836,
#  'rxn07295_c': 0.38840603828430176,
#  'rxn01444_c': 0.4148488938808441,
#  'rxn10287_c': 0.7790300846099854,
#  'rxn00139_c': 0.5597951412200928,
#  'rxn01446_c': 0.6076274514198303,
#  'rxn02358_c': 0.987697422504425,
#  'rxn10283_c': 0.8778653144836426,
#  'rxn08202_c': 0.970028281211853,
#  'rxn02934_c': 0.9838442206382751,
#  'rxn09111_c': 0.8705690503120422,
#  'rxn03384_c': 0.24047112464904785,
#  'rxn05612_c': 0.28259027004241943,
#  'rxn10309_c': 0.21845999360084534,
#  'rxn10285_c': 0.6975862979888916,
#  'rxn02171_c': 0.5919405221939087,
#  'rxn01068_c': 0.9229111671447754,
#  'rxn05249_c': 0.5060386061668396,
#  'rxn03910_c': 0.06181424856185913,
#  'rxn12432_c': 0.9414006471633911,
#  'rxn05167_c': 0.4578034579753876,
#  'rxn08089_c': 0.5171544551849365,
#  'rxn01816_c': 0.15163251757621765,
#  'rxn04657_c': 0.09674149751663208,
#  'rxn08094_c': 0.32220393419265747,
#  'rxn00541_c': 0.16918691992759705,
#  'rxn11684_c': 0.06724855303764343,
#  'rxn02056_c': 0.4045283794403076,
#  'rxn00189_c': 0.6046057939529419,
#  'rxn10043_c': 0.15944504737854004,
#  'rxn10269_c': 0.12067189812660217,
#  'rxn11946_c': 0.9774459004402161,
#  'rxn02508_c': 0.7941300868988037,
#  'rxn05740_c': 0.21633881330490112,
#  'rxn00134_c': 0.9682149887084961,
#  'rxn02322_c': 0.8395407199859619,
#  'rxn00543_c': 0.2654619812965393,
#  'rxn01996_c': 0.26194584369659424,
#  'rxn06022_c': 0.9185411930084229,
#  'rxn02504_c': 0.21743515133857727,
#  'rxn00422_c': 0.6733028292655945,
#  'rxn04082_c': 0.9025624990463257,
#  'rxn09992_c': 0.8132824897766113,
#  'rxn05627_c': 0.6455322504043579,
#  'rxn10340_c': 0.9864077568054199,
#  'rxn04047_c': 0.1718931496143341,
#  'rxn00132_c': 0.6403424143791199,
#  'rxn01028_c': 0.6215012669563293,
#  'rxn05557_c': 0.7921470403671265,
#  'rxn01912_c': 0.12643370032310486,
#  'rxn10342_c': 0.4087822735309601,
#  'rxn04045_c': 0.6686503291130066,
#  'rxn03540_c': 0.7380567193031311,
#  'rxn10207_c': 0.8158576488494873,
#  'rxn10223_c': 0.040818601846694946,
#  'rxn04160_c': 0.9457302093505859,
#  'rxn10221_c': 0.91660475730896,
#  'rxn07589_c': 0.3325344920158386,
#  'rxn12850_c': 0.0974591076374054,
#  'rxn08086_c': 0.2974584698677063,
#  'rxn00262_c': 0.659733235836029,
#  'rxn03173_c': 0.9867196083068848,
#  'rxn00713_c': 0.8646001815795898,
#  'rxn02792_c': 0.37782764434814453,
#  'rxn02331_c': 0.05775454640388489,
#  'rxn04658_c': 0.4586273431777954,
#  'rxn02596_c': 0.4793712794780731,
#  'rxn10476_c': 0.4981275498867035,
#  'rxn08311_c': 0.8681336045265198,
#  'rxn10262_c': 0.1729552447795868,
#  'rxn01100_c': 0.9776920676231384,
#  'rxn00991_c': 0.12536749243736267,
#  'rxn03919_c': 0.5178666114807129,
#  'rxn03175_c': 0.46309322118759155,
#  'rxn10260_c': 0.5832372903823853,
#  'rxn10126_c': 0.5868455171585083,
#  'rxn10319_c': 0.5245257616043091,
#  'rxn00469_c': 0.15144219994544983,
#  'rxn10266_c': 0.14915987849235535,
#  'rxn00295_c': 0.688170313835144,
#  'rxn10264_c': 0.9803227186203003,
#  'rxn10124_c': 0.3593112528324127,
#  'rxn12642_c': 0.40885019302368164,
#  'rxn01990_c': 0.8448396325111389,
#  'rxn02804_c': 0.2149333357810974,
#  'rxn00166_c': 0.23164433240890503,
#  'rxn05005_c': 0.2996528744697571,
#  'rxn00548_c': 0.20016691088676453,
#  'rxn00160_c': 0.012623220682144165,
#  'rxn00544_c': 0.8825422525405884,
#  'rxn09152_c': 0.4902535676956177,
#  'rxn01924_c': 0.9478437900543213,
#  'rxn03075_c': 0.10066771507263184,
#  'rxn01893_c': 0.12017512321472168,
#  'rxn02939_c': 0.9412089586257935,
#  'rxn00260_c': 0.09423589706420898,
#  'rxn03421_c': 0.19709143042564392,
#  'rxn02985_c': 0.9369214773178101,
#  'rxn01508_c': 0.22689536213874817,
#  'rxn05455_c': 0.9587304592132568,
#  'rxn09996_c': 0.39471396803855896,
#  'rxn04048_c': 0.17764529585838318,
#  'rxn10227_c': 0.660698652267456,
#  'rxn01368_c': 0.18508610129356384,
#  'rxn01146_c': 0.15754055976867676,
#  'rxn08084_c': 0.6241405606269836,
#  'rxn10225_c': 0.981765866279602,
#  'rxn00347_c': 0.5586268305778503,
#  'rxn00629_c': 0.7088428735733032,
#  'rxn00898_c': 0.34226661920547485,
#  'rxn00265_c': 0.7503482699394226,
#  'rxn05336_c': 0.2822237014770508,
#  'rxn05334_c': 0.4901456832885742,
#  'rxn01480_c': 0.9380829930305481,
#  'rxn00100_c': 0.2959716320037842,
#  'rxn00853_c': 0.9575739502906799,
#  'rxn05180_c': 0.7388204336166382,
#  'rxn05040_c': 0.5637201070785522,
#  'rxn03034_c': 0.6574178338050842,
#  'rxn05939_c': 0.1810329258441925,
#  'rxn09210_c': 0.36759716272354126,
#  'rxn02360_c': 0.9144279956817627,
#  'rxn01484_c': 0.07198020815849304,
#  'rxn00768_c': 0.011721789836883545,
#  'rxn05231_c': 0.8733202815055847,
#  'rxn03030_c': 0.5075089931488037,
#  'rxn00892_c': 0.37666502594947815,
#  'rxn04712_c': 0.6743075847625732,
#  'rxn02112_c': 0.08596107363700867,
#  'rxn05184_c': 0.1661929190158844,
#  'rxn00337_c': 0.8742648959159851,
#  'rxn05235_c': 0.6844489574432373,
#  'rxn00162_c': 0.04437980055809021,
#  'rxn05233_c': 0.9876687526702881,
#  'rxn09109_c': 0.0809507668018341,
#  'rxn05546_c': 0.20415928959846497,
#  'rxn05377_c': 0.10479211807250977,
#  'rxn05582_c': 0.6498357653617859,
#  'rxn00283_c': 0.44974714517593384,
#  'rxn05505_c': 0.5664268136024475,
#  'rxn08556_c': 0.8822004795074463,
#  'rxn05540_c': 0.3112744092941284,
#  'rxn01843_c': 0.6164000630378723,
#  'rxn00720_c': 0.16692158579826355,
#  'rxn01200_c': 0.8872100114822388,
#  'rxn00285_c': 0.18400618433952332,
#  'rxn05507_c': 0.685692310333252,
#  'rxn00186_c': 0.8563428521156311,
#  'rxn08558_c': 0.8792127370834351,
#  'rxn01241_c': 0.9798997640609741,
#  'rxn00816_c': 0.7841838598251343,
#  'rxn05373_c': 0.08122533559799194,
#  'rxn00726_c': 0.7092403173446655,
#  'rxn05371_c': 0.7032076120376587,
#  'rxn01298_c': 0.052564144134521484,
#  'rxn00184_c': 0.7048267722129822,
#  'rxn01654_c': 0.20405718684196472,
#  'rxn01750_c': 0.7699511051177979,
#  'rxn01093_c': 0.6120241284370422,
#  'rxn02988_c': 0.5411999225616455,
#  'rxn11937_c': 0.7228882312774658,
#  'rxn05356_c': 0.12752363085746765,
#  'rxn05348_c': 0.0613076388835907,
#  'rxn07584_c': 0.3645986318588257,
#  'rxn01025_c': 0.8818727135658264,
#  'rxn00182_c': 0.17210546135902405,
#  'rxn05501_c': 0.5592396259307861,
#  'rxn05206_c': 0.03412580490112305,
#  'rxn00340_c': 0.8499476313591003,
#  'rxn05332_c': 0.32190030813217163,
#  'rxn01715_c': 0.08537665009498596,
#  'rxn01021_c': 0.15847420692443848,
#  'rxn07586_c': 0.8490455150604248,
#  'rxn05330_c': 0.4792015254497528,
#  'rxn02155_c': 0.8642838597297668,
#  'rxn00165_c': 0.1264876127243042,
#  'rxn10228_c': 0.40919727087020874,
#  'rxn02181_c': 0.9652614593505859,
#  'rxn05549_c': 0.9453861713409424,
#  'rxn02716_c': 0.5908988118171692,
#  'rxn01117_c': 0.2931510806083679,
#  'rxn05378_c': 0.16371649503707886,
#  'rxn09104_c': 0.926008939743042,
#  'rxn00288_c': 0.19566643238067627,
#  'rxn00302_c': 0.8105285167694092,
#  'rxn02185_c': 0.35462719202041626,
#  'rxn02187_c': 0.309338241815567,
#  'rxn09106_c': 0.2867697477340698,
#  'rxn02866_c': 0.3436003029346466,
#  'rxn03020_c': 0.2968420386314392,
#  'rxn05172_c': 0.2400733232498169,
#  'rxn00763_c': 0.33831721544265747,
#  'rxn09102_c': 0.9248167276382446,
#  'rxn05508_c': 0.1873202621936798,
#  'rxn00856_c': 0.6639788150787354,
#  'rxn08550_c': 0.37957608699798584,
#  'rxn05542_c': 0.857271671295166,
#  'rxn00420_c': 0.3100971579551697,
#  'rxn05176_c': 0.7859418988227844,
#  'rxn00539_c': 0.42306792736053467,
#  'rxn08552_c': 0.14683836698532104,
#  'rxn05170_c': 0.5316353440284729,
#  'rxn01204_c': 0.4748102128505707,
#  'rxn02341_c': 0.35126155614852905,
#  'rxn00007_c': 0.7616019248962402,
#  'rxn08811_c': 0.42716002464294434,
#  'rxn01390_c': 0.6615904569625854,
#  'rxn02473_c': 0.9251742362976074,
#  'rxn01275_c': 0.2710452377796173,
#  'rxn05427_c': 0.8763213157653809,
#  'rxn10174_c': 0.04035741090774536,
#  'rxn02475_c': 0.8612070083618164,
#  'rxn05468_c': 0.9309884309768677,
#  'rxn01121_c': 0.5853766202926636,
#  'rxn03843_c': 0.9628630876541138,
#  'rxn00577_c': 0.3330077528953552,
#  'rxn00001_c': 0.08251824975013733,
#  'rxn01513_c': 0.36308038234710693,
#  'rxn03841_c': 0.2848700284957886,
#  'rxn00575_c': 0.4880523085594177,
#  'rxn01618_c': 0.08852434158325195,
#  'rxn08821_c': 0.603111207485199,
#  'rxn05339_c': 0.7361748218536377,
#  'rxn05460_c': 0.908482551574707,
#  'rxn00208_c': 0.6792357563972473,
#  'rxn09685_c': 0.25296369194984436,
#  'rxn05545_c': 0.627211332321167,
#  'rxn08656_c': 0.6293159127235413,
#  'rxn08954_c': 0.44103485345840454,
#  'rxn05484_c': 0.884773850440979,
#  'rxn00467_c': 0.8761811256408691,
#  'rxn10315_c': 0.16586825251579285,
#  'rxn00835_c': 0.3559574782848358,
#  'rxn09448_c': 0.048214495182037354,
#  'rxn01434_c': 0.1852775514125824,
#  'rxn03108_c': 0.0547909140586853,
#  'rxn10313_c': 0.03618374466896057,
#  'rxn03061_c': 0.4604838490486145,
#  'rxn06299_c': 0.15926814079284668,
#  'rxn00710_c': 0.1440759003162384,
#  'rxn00675_c': 0.583869218826294,
#  'rxn01018_c': 0.9767612218856812,
#  'rxn01114_c': 0.027039647102355957,
#  'rxn00912_c': 0.4394400417804718,
#  'rxn04132_c': 0.918189525604248,
#  'rxn05428_c': 0.7829132080078125,
#  'rxn02305_c': 0.6374107003211975,
#  'rxn02928_c': 0.5358163118362427,
#  'rxn00470_c': 0.6063961386680603,
#  'rxn05687_c': 0.26309871673583984,
#  'rxn05644_c': 0.31678181886672974,
#  'rxn06075_c': 0.19711697101593018,
#  'rxn02733_c': 0.8638573288917542,
#  'rxn08817_c': 0.2017633020877838,
#  'rxn12147_c': 0.6403653621673584,
#  'rxn00712_c': 0.40004587173461914,
#  'rxn01203_c': 0.3358042240142822,
#  'rxn05467_c': 0.8839006423950195,
#  'rxn00910_c': 0.8061343431472778,
#  'rxn06077_c': 0.578727662563324,
#  'rxn08819_c': 0.904664933681488,
#  'rxn01201_c': 0.07064792513847351,
#  'rxn05425_c': 0.8310410976409912,
#  'rxn00914_c': 0.11772137880325317,
#  'rxn04162_c': 0.4444410800933838,
#  'rxn10318_c': 0.06528884172439575,
#  'rxn05683_c': 0.07836112380027771,
#  'rxn05602_c': 0.6866170167922974,
#  'rxn05681_c': 0.8842792510986328,
#  'rxn11944_c': 0.8737823963165283,
#  'rxn08615_c': 0.19799786806106567,
#  'rxn04996_c': 0.5400292277336121,
#  'rxn08815_c': 0.4247019290924072,
#  'rxn01129_c': 0.6560450196266174,
#  'rxn00124_c': 0.1715848445892334,
#  'rxn08298_c': 0.811377763748169,
#  'rxn10219_c': 0.731964111328125,
#  'rxn00126_c': 0.9748944640159607,
#  'rxn08296_c': 0.4201154410839081,
#  'rxn01518_c': 0.9192028045654297,
#  'rxn03512_c': 0.048806220293045044,
#  'rxn01291_c': 0.09793564677238464,
#  'rxn00717_c': 0.9821641445159912,
#  'rxn08712_c': 0.33064642548561096,
#  'rxn00634_c': 0.19722691178321838,
#  'rxn05649_c': 0.9839298129081726,
#  'rxn00122_c': 0.5449668169021606,
#  'rxn02029_c': 0.07195976376533508,
#  'rxn08710_c': 0.9678615927696228,
#  'rxn05647_c': 0.8586001396179199,
#  'rxn07191_c': 0.3860991299152374,
#  'rxn01297_c': 0.9827502369880676,
#  'rxn03514_c': 0.27628037333488464,
#  'rxn08793_c': 0.08964923024177551,
#  'rxn09979_c': 0.33159011602401733,
#  'rxn02342_c': 0.5377442240715027,
#  'rxn10311_c': 0.8782097101211548,
#  'rxn03188_c': 0.009721517562866211,
#  'rxn11938_c': 0.6122339963912964,
#  'rxn10338_c': 0.1544840931892395,
#  'rxn02971_c': 0.5591720342636108,
#  'rxn10254_c': 0.18530234694480896,
#  'rxn05300_c': 0.31633734703063965,
#  'rxn02339_c': 0.03196403384208679,
#  'rxn10210_c': 0.11488652229309082,
#  'rxn01015_c': 0.1773456633090973,
#  'rxn09989_c': 0.07338088750839233,
#  'rxn10136_c': 0.8707823753356934,
#  'rxn00985_c': 0.15833887457847595,
#  'rxn05457_c': 0.24374845623970032,
#  'rxn10216_c': 0.25291794538497925,
#  'rxn10212_c': 0.20166903734207153,
#  'rxn01011_c': 0.44122689962387085,
#  'rxn08798_c': 0.6299154758453369,
#  'rxn01682_c': 0.4279729127883911,
#  'rxn08976_c': 0.9601889848709106,
#  'rxn08796_c': 0.9569745659828186,
#  'rxn10132_c': 0.6139747500419617,
#  'rxn01806_c': 0.6890878677368164,
#  'rxn08941_c': 0.18959546089172363,
#  'rxn09240_c': 0.05544000864028931,
#  'rxn00479_c': 0.708763599395752,
#  'rxn00205_c': 0.28102225065231323,
#  'rxn02320_c': 0.059882938861846924,
#  'rxn05175_c': 0.4273642897605896,
#  'rxn03181_c': 0.014965862035751343,
#  'rxn03146_c': 0.14195212721824646,
#  'rxn08294_c': 0.47714635729789734,
#  'rxn05179_c': 0.4048965573310852,
#  'rxn03324_c': 0.9010505080223083,
#  'rxn08618_c': 0.5777209997177124,
#  'rxn11650_c': 0.17426788806915283,
#  'rxn03893_c': 0.15311077237129211,
#  'rxn02789_c': 0.676430344581604,
#  'rxn04705_c': 0.1253657042980194,
#  'rxn05247_c': 0.9946377277374268,
#  'rxn03842_c': 0.6491521596908569,
#  'rxn10259_c': 0.028465598821640015,
#  'rxn00988_c': 0.565138578414917,
#  'rxn01602_c': 0.5631428956985474,
#  'rxn00058_c': 0.45544230937957764,
#  'rxn05034_c': 0.9490692019462585,
#  'rxn05453_c': 0.4804064631462097,
#  'rxn03068_c': 0.07189774513244629,
#  'rxn05451_c': 0.879203736782074,
#  'rxn06493_c': 0.09965068101882935,
#  'rxn00783_c': 0.891565203666687,
#  'rxn10214_c': 0.8808424472808838,
#  'rxn12846_c': 0.972761332988739,
#  'rxn05223_c': 0.33488112688064575,
#  'rxn10307_c': 0.34980934858322144,
#  'rxn04158_c': 0.4743218719959259,
#  'rxn09202_c': 0.14838051795959473,
#  'rxn09200_c': 0.7262779474258423,
#  'rxn02102_c': 0.6274359226226807,
#  'rxn10213_c': 0.9653769731521606,
#  'rxn08306_c': 0.13313746452331543,
#  'rxn05221_c': 0.2830686867237091,
#  'rxn08308_c': 0.2983979880809784,
#  'rxn00152_c': 0.974236249923706,
#  'rxn01930_c': 0.8066534996032715,
#  'rxn01333_c': 0.3656243681907654,
#  'rxn01331_c': 0.7296736836433411,
#  'rxn01761_c': 0.8709275722503662,
#  'rxn02925_c': 0.5794406533241272,
#  'rxn08467_c': 0.03239893913269043,
#  'rxn11268_c': 0.1136455237865448,
#  'rxn08823_c': 0.6380670070648193,
#  'rxn05031_c': 0.3388378918170929,
#  'rxn10257_c': 0.9832072257995605,
#  'rxn06586_c': 0.9081318378448486,
#  'rxn02927_c': 0.036905884742736816,
#  'rxn00206_c': 0.6225009560585022,
#  'rxn00947_c': 0.04974961280822754,
#  'rxn03247_c': 0.053128987550735474,
#  'rxn05381_c': 0.157878577709198,
#  'rxn05344_c': 0.8308311700820923,
#  'rxn00114_c': 0.5501312017440796,
#  'rxn00440_c': 0.7788620591163635,
#  'rxn03241_c': 0.3198992609977722,
#  'rxn08713_c': 0.8763688802719116,
#  'rxn01871_c': 0.3859609365463257,
#  'rxn09144_c': 0.2345762550830841,
#  'rxn00151_c': 0.11770623922348022,
#  'rxn05340_c': 0.07866299152374268,
#  'rxn09148_c': 0.16698899865150452,
#  'rxn12510_c': 0.8831838369369507,
#  'rxn08703_c': 0.27970972657203674,
#  'rxn00867_c': 0.5562646985054016,
#  'rxn05342_c': 0.40898382663726807,
#  'rxn04152_c': 0.7095822691917419,
#  'rxn00331_c': 0.2387760877609253,
#  'rxn03394_c': 0.42406004667282104,
#  'rxn04154_c': 0.53429114818573,
#  'rxn00407_c': 0.945866584777832,
#  'rxn00484_c': 0.347713828086853,
#  'rxn00405_c': 0.5919997692108154,
#  'rxn04704_c': 0.49644988775253296,
#  'rxn00333_c': 0.34053415060043335,
#  'rxn01523_c': 0.49228864908218384,
#  'rxn12512_c': 0.34096306562423706,
#  'rxn03248_c': 0.29710710048675537,
#  'rxn05146_c': 0.5841299295425415,
#  'rxn05307_c': 0.7112946510314941,
#  'rxn01169_c': 0.39956986904144287,
#  'rxn05386_c': 0.07964968681335449,
#  'rxn01521_c': 0.36974456906318665,
#  'rxn05737_c': 0.1587037742137909,
#  'rxn00146_c': 0.7234774231910706,
#  'rxn01872_c': 0.38517436385154724,
#  'rxn05516_c': 0.03775835037231445,
#  'rxn00299_c': 0.11537998914718628,
#  'rxn09110_c': 0.7906283140182495,
#  'rxn05733_c': 0.8399581909179688,
#  'rxn08129_c': 0.18056067824363708,
#  'rxn08546_c': 0.71345055103302,
#  'rxn00827_c': 0.9673634767532349,
#  'rxn05144_c': 0.26009851694107056,
#  'rxn03978_c': 0.7831594944000244,
#  'rxn01640_c': 0.23507800698280334,
#  'rxn02270_c': 0.8882270455360413,
#  'rxn01830_c': 0.4274485111236572,
#  'rxn09206_c': 0.5862453579902649,
#  'rxn00756_c': 0.4870082139968872,
#  'rxn05389_c': 0.5199506282806396,
#  'rxn01644_c': 0.14157003164291382,
#  'rxn03243_c': 0.8311324119567871,
#  'rxn01729_c': 0.21742266416549683,
#  'rxn04159_c': 0.21446403861045837,
#  'rxn08900_c': 0.5512295961380005,
#  'rxn01642_c': 0.8881891965866089,
#  'rxn08620_c': 0.6781466007232666,
#  'rxn02376_c': 0.9444111585617065,
#  'rxn09143_c': 0.6618978381156921,
#  'rxn03991_c': 0.32291167974472046,
#  'rxn05594_c': 0.9421452283859253,
#  'rxn00159_c': 0.30751174688339233,
#  'rxn05414_c': 0.37200093269348145,
#  'rxn00082_c': 0.8540856838226318,
#  'rxn05406_c': 0.30962884426116943,
#  'rxn05598_c': 0.7928349375724792,
#  'rxn09147_c': 0.4831124544143677,
#  'rxn10147_c': 0.5725138187408447,
#  'rxn05596_c': 0.09392046928405762,
#  'rxn10180_c': 0.586658239364624,
#  'rxn09141_c': 0.5152044892311096,
#  'rxn00292_c': 0.8158395290374756,
#  'rxn02279_c': 0.10004213452339172,
#  'rxn04027_c': 0.4584289789199829,
#  'rxn07492_c': 0.7545129060745239,
#  'rxn00290_c': 0.5064204335212708,
#  'rxn10182_c': 0.5419661402702332,
#  'rxn09209_c': 0.8735160827636719,
#  'rxn05514_c': 0.7185938358306885,
#  'rxn10148_c': 0.40696388483047485,
#  'rxn03244_c': 0.14314359426498413,
#  'rxn05735_c': 0.152166485786438,
#  'rxn00526_c': 0.21202659606933594,
#  'rxn00338_c': 0.6314295530319214,
#  'rxn05512_c': 0.3087656497955322,
#  'rxn05384_c': 0.1630769968032837,
#  'rxn05902_c': 0.8394495248794556,
#  'rxn00799_c': 0.8399534225463867,
#  'rxn01975_c': 0.1079338788986206,
#  'rxn09160_c': 0.982702374458313,
#  'rxn00904_c': 0.35663390159606934,
#  'rxn08127_c': 0.8364505767822266,
#  'rxn01977_c': 0.8397875428199768,
#  'rxn02374_c': 0.07198241353034973,
#  'rxn02373_c': 0.04954013228416443,
#  'rxn02484_c': 0.5602315664291382,
#  'rxn00902_c': 0.10208693146705627,
#  'rxn10067_c': 0.9560365676879883,
#  'rxn01073_c': 0.7645334601402283,
#  'rxn05671_c': 0.7415205836296082,
#  'rxn01649_c': 0.44620588421821594,
#  'rxn03839_c': 0.8862200975418091,
#  'rxn02405_c': 0.8740448951721191,
#  'rxn05063_c': 0.943964958190918,
#  'rxn00011_c': 0.1365833282470703,
#  'rxn01647_c': 0.13327878713607788,
#  'rxn05418_c': 0.8724122047424316,
#  'rxn05287_c': 0.9440304040908813,
#  'rxn04597_c': 0.699743390083313,
#  'rxn01133_c': 0.3264055550098419,
#  'rxn00449_c': 0.036344945430755615,
#  'rxn10060_c': 0.9619563817977905,
#  'rxn07430_c': 0.5828222632408142,
#  'rxn01986_c': 0.976883053779602,
#  'rxn00085_c': 0.35702818632125854,
#  'rxn01737_c': 0.11497494578361511,
#  'rxn03159_c': 0.6229520440101624,
#  'rxn00119_c': 0.2502903342247009,
#  'rxn02200_c': 0.8834258317947388,
#  'rxn06672_c': 0.9398512244224548,
#  'rxn02529_c': 0.6036736965179443,
#  'rxn00709_c': 0.974495530128479,
#  'rxn00871_c': 0.08393031358718872,
#  'rxn07432_c': 0.9483574628829956,
#  'rxn00649_c': 0.9146860241889954,
#  'rxn10321_c': 0.8273985385894775,
#  'rxn05526_c': 0.5482094287872314,
#  'rxn05493_c': 0.6274881958961487,
#  'rxn00602_c': 0.8226234912872314,
#  'rxn02400_c': 0.5409250259399414,
#  'rxn00875_c': 0.6111229062080383,
#  'rxn01268_c': 0.6107984781265259,
#  'rxn09162_c': 0.8520858883857727,
#  'rxn01000_c': 0.6590134501457214,
#  'rxn00395_c': 0.25315073132514954,
#  'rxn10323_c': 0.9821222424507141,
#  'rxn05528_c': 0.10492175817489624,
#  'rxn03397_c': 0.8796016573905945,
#  'rxn00791_c': 0.5256525278091431,
#  'rxn00702_c': 0.15698447823524475,
#  'rxn00641_c': 0.6778901815414429,
#  'rxn02377_c': 0.6597996354103088,
#  'rxn10335_c': 0.9638853073120117,
#  'rxn06874_c': 0.12468013167381287,
#  'rxn00691_c': 0.37882912158966064,
#  'rxn03150_c': 0.03777766227722168,
#  'rxn00361_c': 0.5150570869445801,
#  'rxn05108_c': 0.057766854763031006,
#  'rxn05957_c': 0.0364227294921875,
#  'rxn00588_c': 0.03239154815673828,
#  'rxn00065_c': 0.03071388602256775,
#  'rxn10336_c': 0.9059603214263916,
#  'rxn00365_c': 0.20665517449378967,
#  'rxn02788_c': 0.08705401420593262,
#  'rxn08708_c': 0.07987773418426514,
#  'rxn00646_c': 0.9971606135368347,
#  'rxn00363_c': 0.1483679711818695,
#  'rxn05398_c': 0.6303849220275879,
#  'rxn01285_c': 0.18234485387802124,
#  'rxn08128_c': 0.5485653281211853,
#  'rxn05188_c': 0.5034408569335938,
#  'rxn08549_c': 0.9972485303878784,
#  'rxn09657_c': 0.9307082891464233,
#  'rxn01423_c': 0.578324556350708,
#  'rxn01972_c': 0.15627026557922363,
#  'rxn00608_c': 0.15009990334510803,
#  'rxn08783_c': 0.9489910006523132,
#  'rxn09129_c': 0.24562153220176697,
#  'rxn01281_c': 0.670842170715332,
#  'rxn07434_c': 0.9217938184738159,
#  'rxn01974_c': 0.9053470492362976,
#  'rxn00358_c': 0.9583185911178589,
#  'rxn09127_c': 0.7077183127403259,
#  'rxn02911_c': 0.779494047164917,
#  'rxn09137_c': 0.370431125164032,
#  'rxn00686_c': 0.5046277046203613,
#  'rxn05441_c': 0.5569453835487366,
#  'rxn00048_c': 0.19516262412071228,
#  'rxn05452_c': 0.10981374979019165,
#  'rxn01672_c': 0.794635534286499,
#  'rxn05543_c': 0.1943383514881134,
#  'rxn01670_c': 0.13496601581573486,
#  'rxn05443_c': 0.9880728721618652,
#  'rxn08203_c': 0.6982268691062927,
#  'rxn12641_c': 0.6398036479949951,
#  'rxn04454_c': 0.7136536836624146,
#  'rxn10208_c': 0.3387467563152313,
#  'rxn05445_c': 0.8670320510864258,
#  'rxn05447_c': 0.6431228518486023,
#  'rxn12643_c': 0.5964571833610535,
#  'rxn02522_c': 0.4415521025657654,
#  'rxn04673_c': 0.12404391169548035,
#  'rxn00568_c': 0.11906015872955322,
#  'rxn08844_c': 0.06536313891410828,
#  'rxn01633_c': 0.7604109048843384,
#  'rxn05449_c': 0.5112391710281372,
#  'rxn09101_c': 0.30554983019828796,
#  'rxn08971_c': 0.8587527275085449,
#  'rxn10206_c': 0.8799833059310913,
#  'rxn00979_c': 0.5542923212051392,
#  'rxn04020_c': 0.9250351190567017,
#  'rxn01706_c': 0.8320642709732056,
#  'rxn05316_c': 0.07281500101089478,
#  'rxn01466_c': 0.8486136198043823,
#  'rxn00529_c': 0.9825344085693359,
#  'rxn05104_c': 0.16593238711357117,
#  'rxn01637_c': 0.6339833736419678,
#  'rxn05106_c': 0.7635724544525146,
#  'rxn10202_c': 0.47913995385169983,
#  'rxn01646_c': 0.6337820291519165,
#  'rxn05450_c': 0.14376267790794373,
#  'rxn02483_c': 0.7005490064620972,
#  'rxn03055_c': 0.14395111799240112,
#  'rxn10294_c': 0.9791653156280518,
#  'rxn01486_c': 0.6967249512672424,
#  'rxn08471_c': 0.43698328733444214,
#  'rxn03057_c': 0.4989941120147705,
#  'rxn03406_c': 0.9318313598632812,
#  'rxn10290_c': 0.06840279698371887,
#  'rxn00933_c': 0.6912959814071655,
#  'rxn01304_c': 0.995774507522583,
#  'rxn06848_c': 0.19488605856895447,
#  'rxn10296_c': 0.2904971241950989,
#  'rxn11703_c': 0.9873713254928589,
#  'rxn04384_c': 0.619515061378479,
#  'rxn01300_c': 0.8666782379150391,
#  ...}

# %% [markdown]
# What if we only have a list of reaction ids? (following part can maybe be integrated in make prediction function, this was a bit of a random idea but it seems to work)

# %%
#creates a random list of 500 reactions
rand_reaction_set = np.random.choice(rxn_ids, 500, replace=False)

#converts this to the right format
b_list = NN_Predictor.convert_reaction_list(rand_reaction_set)

# %% [markdown]
# # Multiple predictions
#
# We can also make predictions for multiple models at the same time, starting with a reaction presence dataframe where the rows are the different reactions and the columns are the model ids:

# %%
#multiple binary reaction lists (csv)
input_path = file_path+'/Sample_reaction_presence.csv'
df = pd.read_csv(input_path, index_col=0)
model_ids = df.columns
rxn_ids = df.index
input_data= df.to_numpy().T

# %% [markdown]
# we can then create a prediction with the same order of reaction and model ids

# %%
#   load network and make prediction
prediction = NN_Predictor.make_prediction(input_data,NN)
df_p = pd.DataFrame(index=rxn_ids, columns=model_ids, data=prediction)
df_p.to_csv(output_path+'/Multiple_NN_predictions.csv')

# %%
df_p
# Out:
#                 573074.3     1038927.4  2136177.3      693444.3  1267768.4  \
# rxn00836_c  9.998161e-01  9.999973e-01   0.884641  9.999725e-01   0.769475
# rxn02201_c  9.994148e-01  1.000000e+00   0.996596  9.999999e-01   0.996973
# rxn09126_c  1.192093e-07  4.738569e-06   0.000000  1.430511e-06   0.000000
# rxn05440_c  9.721518e-05  9.992779e-01   0.999786  9.996909e-01   0.999981
# rxn05156_c  7.726848e-04  5.960464e-08   0.000486  4.172325e-07   0.000071
# ...                  ...           ...        ...           ...        ...
# rxn03395_c  6.884336e-06  9.999667e-01   0.999933  9.999970e-01   0.999990
# rxn00330_c  9.318737e-01  9.961246e-01   0.953479  9.990464e-01   0.948009
# rxn05147_c  1.303196e-03  1.788139e-07   0.002296  5.364418e-07   0.000022
# rxn03445_c  2.600658e-02  9.999993e-01   0.999630  9.999993e-01   0.999614
# rxn00839_c  9.999714e-01  9.999998e-01   0.999886  1.000000e+00   0.999977
#
#             1952948.3  1952881.3  1163752.6   84724.3
# rxn00836_c   0.998747   0.918376   0.000431  0.996692
# rxn02201_c   0.999912   0.981015   0.006763  0.997870
# rxn09126_c   0.000133   0.000010   0.000009  0.000000
# rxn05440_c   0.999955   0.999986   0.001043  1.000000
# rxn05156_c   0.000036   0.000097   0.000031  0.000044
# ...               ...        ...        ...       ...
# rxn03395_c   0.000002   0.002735   0.005030  0.000239
# rxn00330_c   0.000918   0.092615   0.000207  0.971920
# rxn05147_c   0.000664   0.000491   0.000112  0.000124
# rxn03445_c   0.991813   0.999343   0.126049  0.999765
# rxn00839_c   0.847790   0.953026   0.017678  1.000000
#
# [1970 rows x 9 columns]
